# %% [markdown]
# <a href="https://colab.research.google.com/github/RodrigoTenorio86/DATA_MINING_CONCEITOS_E_APLICACOES/blob/master/Avaliacacao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from mlxtend.frequent_patterns import  apriori
from mlxtend.frequent_patterns import association_rules

# %%
data = pd.read_excel('/content/base-vendas.xlsx')
data.head()
# Out:
#    Pedido                              Produto  ...  CodigoCliente            Pais
# 0  536365   WHITE HANGING HEART T-LIGHT HOLDER  ...        17850.0  United Kingdom
# 1  536365                  WHITE METAL LANTERN  ...        17850.0  United Kingdom
# 2  536365       CREAM CUPID HEARTS COAT HANGER  ...        17850.0  United Kingdom
# 3  536365  KNITTED UNION FLAG HOT WATER BOTTLE  ...        17850.0  United Kingdom
# 4  536365       RED WOOLLY HOTTIE WHITE HEART.  ...        17850.0  United Kingdom
#
# [5 rows x 7 columns]

# %%
len(data)
# Out:
# 541909

# %%
transactions = []
for i in range(0, len(data)):
    transactions.append([str(data.values[i,j]) for j in range(0, 7)])

# %%
len(transactions)
# Out:
# 541910

# %%
#Agrupando os dados para analisar os primeiros itens
data.groupby(['Pais'])['Quantidade'].sum().sort_values(ascending=False).head()
# Out:
# Pais
# United Kingdom    4263829
# Netherlands        200128
# EIRE               142637
# Germany            117448
# France             110480
# Name: Quantidade, dtype: int64

# %%
pd.DataFrame(data.groupby(['Pais'])['Quantidade'].sum()).sort_values(["Quantidade"], ascending = False).head()
# Out:
#                 Quantidade
# Pais
# United Kingdom     4263829
# Netherlands         200128
# EIRE                142637
# Germany             117448
# France              110480

# %%
data.isnull().sum()
# Out:
# Pedido                0
# Produto            1454
# Quantidade            0
# DataPedido            0
# Preco                 0
# CodigoCliente    135080
# Pais                  0
# dtype: int64

# %%
data.dropna(axis=0, subset=['Produto'], inplace=True)
len(data)
# Out:
# 540455

# %%
data.isnull().sum()
# Out:
# Pedido                0
# Produto               0
# Quantidade            0
# DataPedido            0
# Preco                 0
# CodigoCliente    133626
# Pais                  0
# dtype: int64

# %%
#Criando a "Cesta" para analisar os itens de um pais
market_basket_United_Kingdom = data[data['Pais'] == "United Kingdom"].groupby(['Pedido','Produto'])['Quantidade']
market_basket_United_Kingdom.head()
# Out:
# 0          6
# 1          6
# 2          8
# 3          6
# 4          6
#           ..
# 541889    12
# 541890     8
# 541891    24
# 541892    24
# 541893    10
# Name: Quantidade, Length: 493973, dtype: int64

# %%
market_basket_EIRE = data[data['Pais'] == "EIRE"].groupby(['Pedido','Produto'])['Quantidade']
market_basket_EIRE.head()
# Out:
# 1404       4
# 1405       6
# 1406       6
# 1407      50
# 1408       6
#           ..
# 539151     2
# 539152     2
# 539153     2
# 539154     2
# 539155     6
# Name: Quantidade, Length: 8196, dtype: int64

# %%
market_basket_EIRE = market_basket_EIRE.sum().unstack().reset_index().fillna(0).set_index('Pedido')

# %%
market_basket_EIRE.head()
# Out:
# Produto   4 PURPLE FLOCK DINNER CANDLES  ...  ZINC WIRE SWEETHEART LETTER TRAY
# Pedido                                   ...
# 536540                              0.0  ...                               0.0
# 536541                              0.0  ...                               0.0
# 536803                              0.0  ...                               0.0
# 536885                              0.0  ...                               0.0
# 536890                              0.0  ...                               0.0
#
# [5 rows x 2027 columns]
